# %%
# !wget https://www.dropbox.com/s/rregnjsr1dt5u1d/quotes.json
# Out:
# --2024-02-28 00:58:49--  https://www.dropbox.com/s/rregnjsr1dt5u1d/quotes.json
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘quotes.json’
#
# quotes.json             [ <=>                ]  77.40K  --.-KB/s    in 0.04s
#
# 2024-02-28 00:58:49 (1.71 MB/s) - ‘quotes.json’ saved [79262]

# %%
# !head -n 5 /content/quotes.json
# Out:
# <!DOCTYPE html>
# <html class="maestro global-header" xmlns="http://www.w3.org/1999/xhtml" lang="en">
# <head><meta charset="utf-8" />
# <meta content="noindex, nofollow, noimageindex" name="robots" />
# <meta content="width=device-width, initial-scale=1" name="viewport" />

# %%
# !ls /content
# Out:
# quotes.json  sample_data

# %%
# !file /content/quotes.json
# Out:
# /content/quotes.json: HTML document, ASCII text, with very long lines (42328)

# %%
# !file -i /content/quotes.json
# Out:
# /content/quotes.json: text/html; charset=us-ascii

# %%
try:
    df = pd.read_json(r'/content/quotes.json', encoding='us-ascii')
except ValueError:
    try:
        df = pd.read_json(r'/content/quotes.json', encoding='latin-1')
    except ValueError:
        raise ValueError("Unable to load JSON file with any encoding.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-187834a2f5cd> in <cell line: 1>()
#       1 try:
# ----> 2     df = pd.read_json(r'/content/quotes.json', encoding='us-ascii')
#       3 except ValueError:
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#
# ...

# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize, sent_tokenize
df = pd.read_json(r'/content/quotes.json')
df.tail()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-d6432d6dcab1> in <cell line: 5>()
#       3 from nltk.stem import PorterStemmer
#       4 from nltk.tokenize import word_tokenize, sent_tokenize
# ----> 5 df = pd.read_json(r'/content/quotes.json')
#       6 df.tail()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...
